# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from PIL import Image

# %%
Image.open('../data/rock.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1920x1080 at 0x11432EEE0>

# %%
print(22)
# Out:
# 22

# %%
rock = Image.open('../data/rock.jpg')

# %%
X = np.array(rock)
X = X.reshape(-1, 3)

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=5)
kmeans.fit(X)
# Out:
# KMeans(n_clusters=5)

# %%
kmeans.labels_
# Out:
# array([2, 2, 2, ..., 1, 1, 1], dtype=int32)

# %%
colors = kmeans.cluster_centers_

# %%
colors = np.array(colors, dtype='uint8')
colors
# Out:
# array([[124, 115, 106],
#        [ 40,  34,  36],
#        [ 61, 106, 131],
#        [229, 162,  63],
#        [132,  61,  37]], dtype=uint8)

# %%
plt.figure(figsize=(6,16))
i = 1
for color in colors:
    plt.subplot(1, 10, i)
    plt.axis("off")
    i+=1
    a = np.zeros((100,100,3), dtype='uint8')
    a[:,:,:] = color
    plt.imshow(a)

# %%
new_img = np.zeros(X.shape, dtype='uint8')

# %%
for ix in range(X.shape[0]):
    new_img[ix] = colors[kmeans.labels_[ix]]

# %%
new_img = np.reshape(new_img, np.array(rock).shape)

# %%
plt.figure(figsize=(16,7))
plt.imshow(new_img)

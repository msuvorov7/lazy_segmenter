# %% [markdown]
# # Import

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import time
import json

# %%
from sklearn.cluster import KMeans

# %%
# %cd ..
# Out:
# /Users/ruasvmv/PycharmProjects/lazy_segmenter

# %% [markdown]
# # Config

# %%
from src.stages.data_load import data_load
from src.stages.train_model import train_model
from src.stages.evaluate import evaluate_model

# %% [markdown]
# # Load Data

# %%
data_load('params.yaml')
# Out:
# 2022-03-05 12:17:08 INFO     Saved raw data

# %% [markdown]
# # Train

# %%
train_model('params.yaml')
# Out:
# 2022-03-05 12:17:09 INFO     Estimator: kmeans
# 2022-03-05 12:17:09 INFO     Loaded train dataset
# 2022-03-05 12:17:45 INFO     Saved metrics

# %% [markdown]
# # Evaluate

# %%
evaluate_model('params.yaml')
# Out:
# 2022-03-05 12:17:45 INFO     Loaded model
# 2022-03-05 12:17:45 INFO     Loaded test data
# 2022-03-05 12:17:45 INFO     Saved result

# %% [markdown]
# # Result

# %%
from PIL import Image

# %%
Image.open('reports/result.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=971x970 at 0x11071F3A0>

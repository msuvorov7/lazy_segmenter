# %% [markdown]
# # Import

# %%
from PIL import Image

# %%
# %cd ..
# Out:
# /Users/ruasvmv/PycharmProjects/lazy_segmenter

# %% [markdown]
# # Config

# %%
from src.stages.data_load import data_load
from src.stages.train_model import train_model
from src.stages.evaluate import evaluate_model

# %% [markdown]
# # Load Data

# %%
data_load('params.yaml')
# Out:
# 2022-03-04 20:00:48 INFO     Saved raw data

# %% [markdown]
# # Train

# %%
train_model('params.yaml')
# Out:
# 2022-03-04 20:00:49 INFO     Estimator: kmeans
# 2022-03-04 20:00:49 INFO     Loaded train dataset
# 2022-03-04 20:00:55 INFO     Saved metrics

# %% [markdown]
# # Evaluate

# %%
evaluate_model('params.yaml')
# Out:
# 2022-03-04 20:00:55 INFO     Loaded model
# 2022-03-04 20:00:55 INFO     Loaded test data
# 2022-03-04 20:00:55 INFO     Saved result

# %% [markdown]
# # Result

# %%
Image.open('reports/result.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=971x970 at 0x1286DCDC0>
